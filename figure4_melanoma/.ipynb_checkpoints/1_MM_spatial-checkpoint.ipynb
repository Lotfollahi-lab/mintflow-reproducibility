# %%
import os, sys
import scipy
import pandas as pd
pd.set_option('display.max_rows', None)
import scanpy as sc
# import dask
import squidpy as sq
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RUNID=4
#BASE_DIR = f'/nfs/team361/aa36/OnGit/inflow-reproducibility/Analysis/18_Melanoma_Jan20Runs/NonGit/RunOutputs/Jan26_20_00/Output_Path_Run{RUNID}/'
#os.listdir(BASE_DIR)

# %%
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(14,14))

# %%
adata=sc.read_h5ad('/nfs/team361/ls34/inflow/adata_mm_spatial_finalv.h5ad')
def remove_markers(LIST):
        try: 
            LIST = {key: [gene for gene in genes if gene in adata.var_names] 
                               for key, genes in LIST.items()}
        except: 
            LIST =[gene for gene in LIST if gene in adata_5k.var_names]
        return LIST


try:
    adata.obs["NICHE_NAMES"] = adata.obs["niche_name"]
except:
    adata
adata

# %%
muxspl=adata.obsm["inflow_muxspl"]

# %% [markdown]
# # fig 4a

# %%
#adata.obs['spatial_signal'] = np.sum(muxspl, 1) / np.array(adata.X.sum(1).tolist()).flatten()
adata.obs['spatial_signal'] = np.sum(muxspl, 1) / np.array(adata.obsm["inflow_muxspl_before_sc_pp_normalize_total"].sum(1).tolist()).flatten()
for info_id in set(adata.obs['info_id']):
    sc.pl.spatial(
        adata[adata.obs['info_id']==info_id],
        color=['spatial_signal'],
        spot_size=10.0,
        wspace=0.5,
        #palette=sns.color_palette("Paired"),
        cmap='seismic',
        title=['tissue {} \n colored by spatial_signa'.format(info_id)],
        vmax=300,
        vmin=-100
    )

# %%
sc.settings.set_figure_params(dpi_save=300, dpi=300, facecolor="white", frameon=False, figsize=(6,6))

#adata.obs['spatial_signal'] = np.sum(muxspl, 1) / np.array(adata.X.sum(1).tolist()).flatten()
adata.obs['spatial_signal'] = np.sum(muxspl, 1) / np.array(adata.obsm["inflow_muxspl_before_sc_pp_normalize_total"].sum(1).tolist()).flatten()
for info_id in set(adata.obs['info_id']):
    sc.pl.spatial(
        adata[adata.obs['info_id']==info_id],
        color=['spatial_signal'],
        spot_size=10.0,
        wspace=0.5,
        #palette=sns.color_palette("Paired"),
        cmap='bwr',
        title=['tissue {} \n colored by spatial_signa'.format(info_id)],
        vmax=300,
        vmin=-100,
        save="fig4a.pdf"
    )

# %% [markdown]
# # fig 4c

# %%
key_celltype="broad_celltypes"
CATEGORY = "spatial_niche"

# %%
sc.pl.umap(
    adata,
    color=['spatial_niche'],
    s=20,
    legend_loc="on data",
    legend_fontsize=10,
    legend_fontoutline=2,
            edgecolor="black",
        linewidth=0.1,
 #   save="spatial_umap_mm.pdf",
    title=""
)

# %%
# sq.pl.spatial_scatter(
#         adata,
#         library_id="spatial",
#         shape=None,
#         color=f'spatial_niche',
#         size=1,
#         title='',
#     save="spatial_by_space_size1.pdf"
#     )

# %% [markdown]
# # fig 4f

# %%
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(14,14))

sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=f'spatial_niche',
        size=2,
        title='',

  #  save="spatial_by_space_size2.pdf"
    )

# %%
# sq.pl.spatial_scatter(
#         adata,
#         library_id="spatial",
#         shape=None,
#         color=f'spatial_niche',
#         size=5,
#         title='',
#     edgecolor='black',
#     linewidth=0.05,
#     save="spatial_by_space_size2_with_thicker_outline.pdf"
#     )

# %%
# sq.pl.spatial_scatter(
#         adata,
#         library_id="spatial",
#         shape=None,
#         color=f'spatial_niche',
#         size=5,
#         title='',
#     edgecolor='black',
#     linewidth=0.02,
#     save="spatial_by_space_size2_with_outline.pdf"
#     )

# %%
# adata_i =adata[adata.obs["broad_celltypes"].str.startswith("F")]
# adata_i.obs["broad_celltypes"].value_counts()

# %%
# adata_i.write('/nfs/team361/ls34/inflow/adata_mm_fbs_spatial.h5ad')

# %% [markdown]
# # fig 4j

# %%
sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=['LOXL1'],
        size=10,
        title='',
        vmax=20,
 save="LOXL__umap.pdf"
    )

# %%
sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=['COL5A1'],
        size=10,
        title='',
        vmax=20,
    save="col5a1__umap.pdf"
    )

# %%
sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=['CXCL12'],
        size=1,
        title='',
        vmax=20,
 #   save="cxcl19__umap.pdf"
    )

# %% [markdown]
# # fig 4g

# %%
sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=['MLANA', 'SOX10', 'PRAME', "MELTF"],
        size=1,
        title='',
        vmax=20,
   # save="Melanoma_degs_by_space_toprow.pdf"
    )

# %%
sq.pl.spatial_scatter(
        adata,
        library_id="spatial",
        shape=None,
        color=['EDNRB', 'CST1', 'BAALC', "GDF15"],
        size=1,
        title='',
        vmax=20,
#save="Melanoma_degs_by_space_bottomrow.pdf"
    )

# %%
CATEGORY = 'spatial_niche'
ADATA = adata

sc.tl.rank_genes_groups(adata, CATEGORY, method='t-test', key_added="de_leiden");
df2 = pd.DataFrame(adata.uns['de_leiden']['names'])
for i,x in enumerate(df2.columns):
     print(i,":",x)

# %%
DEGS = []
for select_population in list(df2.columns):
    print(select_population)

    genes0 = list(df2[select_population][:10])
    DEGS.extend(genes0)


sc.pl.matrixplot(
    ADATA,
    DEGS,
    groupby=CATEGORY,
    standard_scale="var",
    dendrogram=False,
    cmap="Reds",
       # save="spatial_degs.pdf"

)

# %%
select_population = list(df2.columns)[-2
                                     ]
CATEGORY="spatial_niche"
print(select_population)

genes0 = df2[select_population][:50]
genes_extended = df2[select_population][0:100]
genes2 = df2[select_population][100:150]
 

sc.pl.matrixplot(
    ADATA,
    genes0,
    groupby=CATEGORY,
    standard_scale="var",
    dendrogram=False,
    cmap="Reds",
     #   save="spatial_MCP_stroma.pdf"

)


sc.pl.matrixplot(
    ADATA,
    genes0,
    groupby=CATEGORY,
    standard_scale="var",
    dendrogram=False,
    cmap="Reds",
#save="spatial_MCP_stroma_100genes.pdf"

)

# %%
# sc.pl.dotplot(
#     ADATA,
#     ["CXCL12"],
#     groupby="spatial_niche",
#     standard_scale="var",
#     dendrogram=False,
#     cmap="Reds",
#        # save="DOTPLOT_CXCL12.pdf"

# )

# %%
KEEP = [#'KCinflamm_late',
# 'KCinflamm_final',
 #'KCinflamm_int',
 #'KCinflamm_basal',
 'cDC2',
 'LC',
 'T',
 'Mast cell',
 #'Melanoma',
 #'F6: Myofibroblast inflammatory',
 #'F1: Superficial',
 'Mac',
 #'Nonspecific',
 'Plasma cell',
 #'Pericyte',
 'cDC1',
 #'LE',
 #'F6: Myofibroblast',
 #'VE',
 'MigDC']
adata_immune = adata[adata.obs[key_celltype].isin(KEEP)]
sc.pl.dotplot(
    adata_immune,
    ["CXCL12", "CCL19"],
    groupby=key_celltype,
    standard_scale="var",
    dendrogram=False,
    cmap="Reds",
       # save="DOTPLOT_CXCL12_CCL19_immunecells.pdf"

)

# %%
colors  = {'KCinflamm_late': '#f4e9ef',
 'KCinflamm_final': '#E07090',
 'KCinflamm_int': '#007FFF',
 'KCinflamm_basal': '#f4e9ef',
 'cDC2': '#6F478C',
 'LC': '#3bc1d9',
 'T': "#FF5F00", #'#F4D1A1',
 'Mast cell': '#927D60',
 'Melanoma': "#8B5A2B",#'#3D1C02',
 #'F6: Myofibroblast inflammatory': 'Cancer-associated fibroblast',
 'Fibroblast': '#FFFFE4',
 'Mac': '#1B03A3',
 'Nonspecific': '#D3D3D3',
 'Plasma cell': '#C2F8FF',
 'Pericyte': '#F7A3C3',
 'cDC1': '#9B70C1',
 'LE': '#FFFF00',
 'Cancer-associated fibroblast':"#52aaff" ,
 'VE': '#d73435',
 'MigDC': '#00FF00'}

# %%
RENAME = {'KCinflamm_late': 'KCinflamm_late',
 'KCinflamm_final': 'KCinflamm_final',
 'KCinflamm_int': 'KCinflamm_int',
 'KCinflamm_basal': 'KCinflamm_basal',
 'cDC2': 'cDC2',
 'LC': 'LC',
 'T': 'T',
 'Mast cell': 'Mast cell',
 'Melanoma': 'Melanoma',
 'F6: Myofibroblast inflammatory': 'Cancer-associated fibroblast',
 'F1: Superficial': 'Fibroblast',
 'Mac': 'Mac',
 'Nonspecific': 'Nonspecific',
 'Plasma cell': 'Plasma cell',
 'Pericyte': 'Pericyte',
 'cDC1': 'cDC1',
 'LE': 'LE',
 'F6: Myofibroblast': 'Cancer-associated fibroblast',
 'VE': 'VE',
 'MigDC': 'MigDC'}
adata.obs["key_celltype_new"]=adata.obs[key_celltype].map(RENAME)

# %%
adata.obs["spatial_niche"].value_counts()

# %%
# ORDER = ['Epidermis', 'Blood vessel', 'Melanoma1', 'Melanoma2',
#          'Plasma cell hub', 'T_hub', 'Mac_hub', 'Stroma', "Perivascular"]

# df = adata.obs.groupby(["spatial_niche", "key_celltype_new"]).size().unstack(fill_value=0)

# df_norm = df.div(df.sum(axis=1), axis=0)

# df_norm = df_norm.loc[:, df_norm.mean() >= 0.002]

# df_norm = df_norm.reindex(ORDER, axis=0).dropna(how="all")

# color_list = [colors.get(cat, "#D3D3D3") for cat in df_norm.columns]

# fig, ax = plt.subplots(figsize=(4, 2))
# df_norm.plot(kind="bar", stacked=True, color=color_list,
#              edgecolor="black", ax=ax, linewidth=0.2)

# ax.grid(False)

# ax.spines["top"].set_visible(False)
# ax.spines["right"].set_visible(False)

# ax.set_title("")

# plt.xlabel(" ")
# plt.ylabel("Proportion")

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles[::-1], labels[::-1], title="", bbox_to_anchor=(1.05, 1),
#           loc="upper left", frameon=False)

# plt.xticks(rotation=90)

# plt.tight_layout()
# #fig.savefig("figures/spatial_composition_barplot.pdf", bbox_inches='tight', dpi=300)

# plt.show()

# %%
adata=adata[adata.obs["key_celltype_new"]!="Nonspecific"]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ---------- inputs ---------------------------------------------------------
ORDER = [
     "Melanoma1", "Melanoma2",
    "Stroma", "T_hub", 
    "Plasma cell hub", "Mac_hub", "Perivascular","Epidermis", "Blood vessel",
]
df = (
    adata.obs
        .groupby(["spatial_niche", "key_celltype_new"])
        .size()
        .unstack(fill_value=0)
)
df_norm = (
    df.div(df.sum(axis=1), axis=0)
      .loc[:, lambda c: c.mean() >= 0.002]          # keep frequent cats
      .reindex(ORDER, axis=0)
      .dropna(how="all")
)

color_list = [colors.get(cat, "#D3D3D3") for cat in df_norm.columns]

# ---------- plot -----------------------------------------------------------
fig, ax = plt.subplots(figsize=(4, 2))
df_norm.plot(
    kind="bar", stacked=True, ax=ax,
    color=color_list, edgecolor="black", linewidth=0.2
)

ax.grid(False)
ax.spines[["top", "right"]].set_visible(False)
ax.set_xlabel("")
ax.set_ylabel("Proportion")
plt.xticks(rotation=90, fontsize=10)     # shrink x-tick labels

# ---------- legend ---------------------------------------------------------
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles[::-1], labels[::-1],
    ncol=4,
    loc="upper center",
    bbox_to_anchor=(0.5, -.8),        # push it lower  ↓↓↓
    frameon=False,
    columnspacing=1.2, handletextpad=0.4,
    fontsize=8,                         # smaller legend text
    title="",
)

plt.tight_layout()
plt.show()

# %%
sc.pl.dotplot(
    adata,
    ["CXCL12"],
    groupby="spatial_niche",
    standard_scale="var",
    dendrogram=False,
)

# %%
# import pandas as pd
# # #adata.uns['log1p']['base'] = None
# CATEGORY = f"spatial_niche"
# #ADATA = adata_i
# adata_ii=adata_i[adata_i.obs["spatial_niche"].isin(["T_hub", "Myofibroblast_T", "Melanoma2", "Melanoma1"])]
# sc.tl.rank_genes_groups(adata_ii, CATEGORY, method='t-test', key_added="de_leiden");
# df2 = pd.DataFrame(adata_ii.uns['de_leiden']['names'])
# for i,x in enumerate(df2.columns):
#      print(i,":",x)

# %%
        
# select_population = list(df2.columns)[0
#                                      ]
# print(select_population)
# GENE_LIST_DEG_ALL =  df2[select_population][:500]
# GENE_LIST_DEG_ALL = [x for x in GENE_LIST_DEG_ALL if x not in MELANOMA_GENES]
# genes0 = GENE_LIST_DEG_ALL[:50]
# genes1 = GENE_LIST_DEG_ALL[50:100]
# genes2 = GENE_LIST_DEG_ALL[100:150]
# genes3 = GENE_LIST_DEG_ALL[150:200]
# genes4 = GENE_LIST_DEG_ALL[200:250]
# genes5 = GENE_LIST_DEG_ALL[250:300]
# genes6 = GENE_LIST_DEG_ALL[300:350]
# genes7 = GENE_LIST_DEG_ALL[350:400]
# genes8 = GENE_LIST_DEG_ALL[400:450]
# genes9 = GENE_LIST_DEG_ALL[450:500]

# sc.pl.dotplot(
#     adata_ii,
#     genes0,
#     groupby=CATEGORY,
#     standard_scale="var",
#     dendrogram=False,
# ) 
# sc.pl.dotplot(
#     adata_ii,
#     genes1,
#     groupby=CATEGORY,
#     standard_scale="var",
#     dendrogram=False,
# ) 
# sc.pl.dotplot(
#     adata_ii,
#     genes2,
#     groupby=CATEGORY,
    
#     standard_scale="var",
#     dendrogram=False,
# ) 
# # sc.pl.dotplot(
# #     adata_subset,
# #     genes3,
# #     groupby="celltype_annotation4",
# #     standard_scale="var",
# #     dendrogram=False,
# # )

# %%
# Define colors for "Melanoma" and "Other"
custom_colors = {
    "Melanoma": "#8B5A2B",  # Light brown
    "Other": "#D3D3D3"  # Light grey
}

# Assign colors to the .uns dictionary in the order they appear in the "mm" category
adata.obs["mm"] = ["Melanoma" if x == "Melanoma" else "Other" for x in adata.obs[key_celltype]]

# Ensure "mm" is a categorical variable
adata.obs["mm"] = adata.obs["mm"].astype("category")

# Store the colors in .uns
adata.uns["mm_colors"] = [custom_colors[cat] for cat in adata.obs["mm"].cat.categories]

# Plot
sq.pl.spatial_scatter(
    adata,
    library_id="spatial",
    shape=None,
    color="mm",
    size=1,
    title="",
    vmax=20,
  #  save="mm_cells.pdf"
)

# %%
# Define colors for "Melanoma" and "Other"
custom_colors = {
    "T": '#FF5F00',   # "#8B5A2B",  # Light brown
    "Other": "#D3D3D3"  # Light grey
}

# Assign colors to the .uns dictionary in the order they appear in the "mm" category
adata.obs["mm"] = ["T" if x == "T" else "Other" for x in adata.obs[key_celltype]]

# Ensure "mm" is a categorical variable
adata.obs["mm"] = adata.obs["mm"].astype("category")

# Store the colors in .uns
adata.uns["mm_colors"] = [custom_colors[cat] for cat in adata.obs["mm"].cat.categories]


# Plot
sq.pl.spatial_scatter(
    adata,
    library_id="spatial",
    shape=None,
    color="mm",
    size=1,
    title="",
    vmax=20,
     #   save="t_cells.pdf",
)

# %%
# Define colors for "Melanoma" and "Other"
custom_colors = {
    "T": '#F4D1A1',   # "#8B5A2B",  # Light brown
    "Other": "#D3D3D3"  # Light grey
}

# Assign colors to the .uns dictionary in the order they appear in the "mm" category
adata.obs["mm"] = ["T" if x == "T" else "Other" for x in adata.obs[key_celltype]]

# Ensure "mm" is a categorical variable
adata.obs["mm"] = adata.obs["mm"].astype("category")

# Store the colors in .uns
adata.uns["mm_colors"] = [custom_colors[cat] for cat in adata.obs["mm"].cat.categories]


# Plot
sq.pl.spatial_scatter(
    adata,
    library_id="spatial",
    shape=None,
    color="mm",
    size=1,
    title="",
    vmax=20,
     #   save="t_cells.pdf",
)

# %%
# Define colors for "Melanoma" and "Other"
custom_colors = {
    "T_hub": "#F4D1A1",   # "#8B5A2B",  # Light brown
    "Other": "#D3D3D3"  # Light grey
}

# Assign colors to the .uns dictionary in the order they appear in the "mm" category
adata.obs["mm"] = [x if x == "T_hub" else "Other" for x in adata.obs["spatial_niche"]]

# Ensure "mm" is a categorical variable
adata.obs["mm"] = adata.obs["mm"].astype("category")

# Store the colors in .uns
adata.uns["mm_colors"] = [custom_colors[cat] for cat in adata.obs["mm"].cat.categories]

# Plot
sq.pl.spatial_scatter(
    adata,
    library_id="spatial",
    shape=None,
    color="mm",
    size=1,
    title="",
    vmax=20,
      #  save="thub_cells.pdf"

    #edgecolor='black',
    #linewidth=0.1
)
 
#     COLORS = {'Epidermis': '#0000FF',
#  'T_hub': '#F4D1A1',
#  'Melanoma2': '#A9A9A9', #BROWN = 5C4033
#  'Blood vessel': '#d73435',
#  'Mac_hub': '#4B0082',
#  'Melanoma1': '#000000',
#  'Myofibroblast_T': '#FFFF00',
#  'Plasma cell hub': '#4DFFFF'}

# %%
# Define colors for "Stroma" and "Other"
custom_colors = {
    "Stroma": "#FFFF00",  # <-- FIXED: Only one `#`
    "Other": "#D3D3D3"
}

# Assign colors to the .uns dictionary in the order they appear in the "mm" category
adata.obs["mm"] = [x if x == "Stroma" else "Other" for x in adata.obs["spatial_niche"]]

# Ensure "mm" is a categorical variable
adata.obs["mm"] = adata.obs["mm"].astype("category")

# Store the colors in .uns
adata.uns["mm_colors"] = [custom_colors[cat] for cat in adata.obs["mm"].cat.categories]

# Plot
sq.pl.spatial_scatter(
    adata,
    library_id="spatial",
    shape=None,
    color="mm",
    size=2,
    title="",
    vmax=20,
 #   save="stroma_cells.pdf"
)

# %%
adata
