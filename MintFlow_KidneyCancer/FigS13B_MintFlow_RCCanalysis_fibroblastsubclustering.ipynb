# %%
## Analysis of Mintflow outputs for renal cell carcinoma dataset
## Fibroblast subclustering
## Dr Daniyal Jafree, Lotfollahi Group, CellGen Programme, Wellcome Sanger Institute
## Final Version - 10th June 2025

# %%
## Set up environment

# local settings, change path if needed
rootdir_inflow = "/nfs/users/nfs_d/dj17/inflow_version3/inflow"  # Change this path if needed

import spatialdata as sd
from spatialdata_io import xenium
import squidpy as sq
from pathlib import Path
import os, sys
import numpy as np
from scipy.sparse import issparse
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import numpy as np
import pandas as pd
import torch
import anndata
import glasbey
from tqdm.autonotebook import tqdm
import gc
import time
import scvi
import os

list_pathstoadd = [
    rootdir_inflow,
    os.path.join(rootdir_inflow, "src"),
    os.path.join(rootdir_inflow, "src", "inflow")
]

for path in list_pathstoadd:
    if(path not in sys.path):
        sys.path.append(path)
        
import inflow

from inflow.cli import parse_config_data_train, parse_config_data_test, parse_config_training, parse_config_model
# Out:
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /tmp/ipykernel_1449245/1520986438.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Set seed
sc.settings.verbosity = 3
sc.settings.seed = 0

# Check if GPU is available
print("GPU Available:", torch.cuda.is_available())
# Check the name of the GPU
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA H100 80GB HBM3

# %%
## Specify input path / results folder and inspect adata

path_results = \
"/nfs/team361/dj17/inflow_inputsandoutputs/inflow_outputs/version4_lowanneal" # N.B.: this was a run performed on 5001 raw genes, with the anneal max set to 0.1 but window size is still large

config_data_test = parse_config_data_test.parse(
    os.path.join(
        path_results,
        'ConfigFilesCopiedOver',
        'config_data_test_DJ_v2.yml' # this has to be copied over from the config file list and present within the results folder
    )
)

adata = sc.read_h5ad(
    os.path.join(
        path_results,
        'adata_inflowOutput_norm.h5ad' # this is the normalised object, but change if required
    )
)

print(adata)
# Out:
# AnnData object with n_obs × n_vars = 337116 × 5001
#     obs: 'batch', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'outlier', '_scvi_batch', '_scvi_labels', 'SCVI_CLUSTERS_KEY', 'cell_area_highlight', 'low_quality_cell_highlight', 'level_1_cell_type', 'level_2_cell_type', 'level_3_cell_type', 'donor', 'inflow_CT', 'inflow_BatchID'
#     uns: 'inflow_map_Batchname_to_inflowBatchID', 'inflow_map_CT_to_inflowCT'
#     obsm: 'X_scVI', 'X_umap', 'inflow_mu_sin', 'inflow_mu_sout', 'inflow_mu_z', 'inflow_muxbar_int', 'inflow_muxbar_spl', 'inflow_muxint', 'inflow_muxint_before_sc_pp_normalize_total', 'inflow_muxspl', 'inflow_muxspl_before_sc_pp_normalize_total', 'spatial'
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_scVI, X_umap, inflow_mu_sin, inflow_mu_sout, inflow_mu_z, inflow_muxbar_int, inflow_muxbar_spl, inflow_muxint, inflow_muxint_before_sc_pp_normalize_total, inflow_muxspl, inflow_muxspl_before_sc_pp_normalize_total, spatial

# %%
## Setup object with naming and colouring

dict_map_prednames_2_readable = {
    'muxint':'Xint',
    'muxspl':'Xspl',
    'muxbar_int':'Xbar_int',
    'muxbar_spl':'Xbar_spl',
    'mu_sin':'S_in',
    'mu_sout':'S_out',
    'mu_z':'Z',
    'muxint_before_sc_pp_normalize_total':'Xint_without_scppnormalizetotal',
    'muxspl_before_sc_pp_normalize_total':'Xspl_without_scppnormalizetotal'
}

for k in dict_map_prednames_2_readable.keys():
    print("inflow_"+k in adata.obsm.keys())
    
for k in dict_map_prednames_2_readable.keys():
    adata.obsm['inflow_{}'.format(dict_map_prednames_2_readable[k])] = adata.obsm['inflow_'+k] + 0
    del adata.obsm['inflow_'+k]
    print("done for ", k)
    gc.collect()
    
for u in adata.obsm.keys():
    print(u)
    
type(adata.obsm['inflow_Xspl']) # should be numpy.ndarray

#key_celltype = 'level_2_cell_type'
#colpal = glasbey.create_palette(
    #palette_size=len(set(adata.obs[key_celltype]))
#)
#sns.palplot(colpal)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# done for  muxint
# done for  muxspl
# done for  muxbar_int
# done for  muxbar_spl
# done for  mu_sin
# done for  mu_sout
# done for  mu_z
# done for  muxint_before_sc_pp_normalize_total
# done for  muxspl_before_sc_pp_normalize_total
# X_scVI
# X_umap
# spatial
# inflow_Xint
# inflow_Xspl
# inflow_Xbar_int
# inflow_Xbar_spl
# inflow_S_in
# inflow_S_out
# inflow_Z
# inflow_Xint_without_scppnormalizetotal
# inflow_Xspl_without_scppnormalizetotal
# numpy.ndarray

# %%
### Predictions are already loaded in in this object, so no need to load them in here

# %%
## Fibroblast subclustering analysis

adata_fibroblast = adata[adata.obs['level_2_cell_type'] == 'Fibroblast'].copy() # Subset the AnnData object
print(adata_fibroblast)
# Out:
# AnnData object with n_obs × n_vars = 43388 × 5001
#     obs: 'batch', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'outlier', '_scvi_batch', '_scvi_labels', 'SCVI_CLUSTERS_KEY', 'cell_area_highlight', 'low_quality_cell_highlight', 'level_1_cell_type', 'level_2_cell_type', 'level_3_cell_type', 'donor', 'inflow_CT', 'inflow_BatchID'
#     uns: 'inflow_map_Batchname_to_inflowBatchID', 'inflow_map_CT_to_inflowCT'
#     obsm: 'X_scVI', 'X_umap', 'spatial', 'inflow_Xint', 'inflow_Xspl', 'inflow_Xbar_int', 'inflow_Xbar_spl', 'inflow_S_in', 'inflow_S_out', 'inflow_Z', 'inflow_Xint_without_scppnormalizetotal', 'inflow_Xspl_without_scppnormalizetotal'
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
# Perform PCA, nearest neighbors and UMAP based on X spatial for endothelium

t_tic = time.time()
varto_use = 'inflow_Xspl'
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
adata_fibroblast.obsm[varto_use+"_PCA"] = pca.fit_transform(adata_fibroblast.obsm[varto_use])
sc.pp.neighbors(adata_fibroblast, use_rep=varto_use+"_PCA")
sc.tl.umap(adata_fibroblast)
sc.pl.umap(
    adata_fibroblast,
    color='level_3_cell_type',
    show=False,
    title=varto_use+"_PCA",
    frameon=False
)
print("Took {} seconds.".format(time.time() - t_tic))
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:15)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:19)
# Took 37.495691776275635 seconds.
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
## Identify spatially-defined endothelial subclusters

# Perform Leiden clustering
sc.tl.leiden(adata_fibroblast, resolution=0.9, key_added='spatial clusters')

# Plot UMAP with the new annotation
sc.pl.umap(adata_fibroblast,
           color=['spatial clusters'],
           title=varto_use + "_PCA_endothelium",
           frameon=False)
# Out:
# running Leiden clustering
#     finished: found 17 clusters and added
#     'spatial clusters', the cluster labels (adata.obs, categorical) (0:00:27)
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
## Spatial plotting of spatially-defined vascular subclusters

batch_id1 = "CV1-KID-0-FO-1"
batch_id2 = "CV1-KID-0-FT-1"
batch_id3 = "CV1-KID-0-FT-2"
batch_id4 = "CV1-KID-0-FT-3"

adata_fibroblast_batch1 = adata_fibroblast[adata_fibroblast.obs['batch'] == batch_id1]
adata_fibroblast_batch2 = adata_fibroblast[adata_fibroblast.obs['batch'] == batch_id2]
adata_fibroblast_batch3 = adata_fibroblast[adata_fibroblast.obs['batch'] == batch_id3]
adata_fibroblast_batch4 = adata_fibroblast[adata_fibroblast.obs['batch'] == batch_id4]

# Plot spatial data
sc.pl.spatial(adata_fibroblast_batch1, color='spatial clusters', size=1.5, spot_size=20, frameon=False)
sc.pl.spatial(adata_fibroblast_batch2, color='spatial clusters', size=1.5, spot_size=20, frameon=False)
sc.pl.spatial(adata_fibroblast_batch3, color='spatial clusters', size=1.5, spot_size=20, frameon=False)
sc.pl.spatial(adata_fibroblast_batch4, color='spatial clusters', size=1.5, spot_size=20, frameon=False)
# Out:
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))

# %%
## Runs preliminary differential expression tests for fibroblasts

# Normalize total counts per cell (if not already done)
sc.pp.normalize_total(adata_fibroblast, target_sum=1e4)
sc.pp.log1p(adata_fibroblast)

# Now run the differential expression analysis using these counts
sc.tl.rank_genes_groups(adata_fibroblast, groupby='spatial clusters', method='wilcoxon')
sc.pl.rank_genes_groups(adata_fibroblast, n_genes=100, sharey=False)

# Optionally, view the top genes per cluster
result = adata_fibroblast.uns['rank_genes_groups']
groups = result['names'].dtype.names  # cluster names
for group in groups:
    print(f"Top genes in {group}:")
    print(result['names'][group][:100])
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# ranking genes
# /nfs/users/nfs_d/dj17/Daniyal_training/DJ_VENV/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:08)
# Top genes in 0:
# ['SLCO2B1' 'SLC40A1' 'CSF1R' 'FCGR2A' 'GPR34' 'MAFB' 'CD14' 'MSR1'
#  'FCGR3A' 'MERTK' 'AP1B1' 'KCNMA1' 'CPVL' 'GAS6' 'C3AR1' 'TBXAS1' 'CYBB'
#  'GAA' 'TREM2' 'AKR1B1' 'MMP14' 'ST14' 'CD68' 'ABCA1' 'SORL1' 'TLR2'
#  'BMP2K' 'PICALM' 'LRP1' 'CSF2RA' 'NCOA4' 'HEXA' 'CTSC' 'NAIP' 'MAN2B1'
#  'CREG1' 'AXL' 'AP2A2' 'SELPLG' 'MEF2A' 'CD84' 'OLFML3' 'STAB1' 'ST6GAL1'
#  'TLR7' 'DST' 'LIPA' 'SLC11A2' 'DAPK1' 'PLXDC1' 'FCGR1A' 'FMN1' 'IFNGR1'
#  'TNFSF13' 'ADAM28' 'TRPM2' 'LAIR1' 'TLR5' 'SNX29' 'CX3CR1' 'CXCL16'
#  'TPCN1' 'FCGR2B' 'PTGER4' 'CD300A' 'ARRB2' 'CXCL12' 'HSPA6' 'VSIG4'
#  'INPPL1' 'ADORA3' 'PTGS1' 'CD163' 'TMEM173' 'MAF' 'AOAH' 'PTPRJ' 'RASSF4'
#  'LPAR5' 'DAB2' 'TGFBR2' 'GRN' 'USP53' 'TSPAN14' 'PDGFC' 'CSF3R' 'SLC43A2'
#  'FOLR2' 'LAMP1' 'CMKLR1' 'CIITA' 'DPYD' 'ABI3' 'CYBA' 'HEXB' 'CTSL'
#  'SLC1A3' 'ATM' 'ITGA4' 'RYR1']
# Top genes in 1:
# ['ANGPTL4' 'NDRG1' 'LDHA' 'CA9' 'ENPEP' 'CA12' 'CDH6' 'PFKP' 'NPTX2'
#  'CD70' 'ENPP3' 'ACLY' 'EGLN3' 'ITGA3' 'MAOA' 'LOX' 'AKR1B1' 'CCND1'
#  'CDKN1A' 'BCL2L1' 'C4B' 'VEGFA' 'PGK1' 'PLIN2' 'ANPEP' 'HIPK2' 'NORAD'
#  'SLC22A2' 'EGFR' 'ERRFI1' 'TGM2' 'THBS2' 'APP' 'TIPARP' 'TSPAN9' 'NEK6'
#  'VCAM1' 'ADM' 'SLC3A1' 'C4A' 'PKM' 'DUSP23' 'TFPI' 'KCNJ15' 'ALDOA'
#  'LAMP2' 'SULF2' 'SLC2A1' 'NRN1' 'SYTL2' 'MXRA7' 'RETREG1' 'FHL1' 'LPCAT1'
#  'CLIC4' 'GPR34' 'CDK18' 'CLPTM1L' 'BNIP3' 'PAM' 'CP' 'TGFA' 'RNF128'
#  'PDZK1' 'P4HB' 'SORL1' 'F2RL1' 'AXL' 'PPP2R1A' 'SLC16A4' 'AEBP1' 'RHOC'
#  'MET' 'MDM2' 'TREM2' 'CANX' 'PCDH10' 'GGT1' 'BHMT' 'FZD4' 'SLC37A4'
#  'SLC9A3R1' 'MERTK' 'GYS1' 'BCKDK' 'TFPI2' 'CTTN' 'TNFRSF21' 'MMP14'
#  'HSPB8' 'FCGR3A' 'THBS1' 'PDIA4' 'GTF2I' 'PDIA3' 'DAB2' 'SERPINE1' 'DST'
#  'NFE2L1' 'FAT1']
# Top genes in 2:
# ['STAB1' 'SLCO2B1' 'CD14' 'CD163' 'MRC1' 'GAS6' 'F13A1' 'CSF1R' 'SIGLEC1'
#  'CXCL12' 'FOLR2' 'SLC40A1' 'LGMN' 'ECRG4' 'AP1B1' 'LILRB5' 'LTBP2' 'CD4'
#  'MAN1A1' 'AP2A2' 'CD209' 'SMAP2' 'MAN2B1' 'NRP1' 'THEMIS2' 'IL2RA' 'CCN2'
#  'NCF4' 'TRPM2' 'SYNPO2' 'FBLN5' 'VSIG4' 'MAF' 'FMN1' 'TPCN1' 'SLIT3'
#  'GRK2' 'GPR34' 'SH3BP5' 'LAMP1' 'GIMAP5' 'LAIR1' 'ENG' 'PDGFRA' 'LENG8'
#  'PID1' 'ICOSLG' 'ZNF683' 'PLTP' 'SFRP1' 'NAIP' 'AOC3' 'PLXDC1' 'CCN1'
#  'MERTK' 'CR1' 'CLEC4M' 'MSR1' 'FRZB' 'TNC' 'RYR1' 'ANKS1A' 'CCDC80'
#  'TNXB' 'GAA' 'MAFB' 'IGF1' 'TNFRSF21' 'COLEC12' 'IKBKB' 'ARRB2' 'TMEM173'
#  'TNFRSF1B' 'MKNK1' 'TCF21' 'PDGFRB' 'ZC3H12D' 'FMO3' 'MYH9' 'DIP2A'
#  'COL5A1' 'IL10RA' 'IRS2' 'KCNQ1' 'NRROS' 'TBXAS1' 'CYP1B1' 'MICAL2'
#  'TIMP2' 'NINJ1' 'GRN' 'CCL19' 'FILIP1L' 'LOXL1' 'C5AR1' 'CYBA' 'METRNL'
#  'TMEM119' 'MYLK' 'CNRIP1']
# Top genes in 3:
# ['NDRG1' 'LDHA' 'ANGPTL4' 'CA9' 'CDH6' 'ENPEP' 'PFKP' 'CA12' 'CD70'
#  'ENPP3' 'ACLY' 'NPTX2' 'LOX' 'APP' 'ITGA3' 'ANPEP' 'MAOA' 'EGLN3' 'C4B'
#  'SLC22A2' 'THBS2' 'C4A' 'HIPK2' 'ADM' 'CCND1' 'CDKN1A' 'EGFR' 'TSPAN9'
#  'SLC3A1' 'VCAM1' 'PKM' 'KCNJ15' 'BCL2L1' 'PGK1' 'TFPI' 'NORAD' 'ERRFI1'
#  'SULF2' 'PLIN2' 'VEGFA' 'TGM2' 'GGT1' 'CP' 'NRN1' 'PAM' 'RNF128' 'SLC2A1'
#  'RETREG1' 'CLIC4' 'TIPARP' 'FHL1' 'MXRA7' 'SLC16A4' 'PCDH10' 'MET'
#  'SYTL2' 'ALDOA' 'PDZK1' 'CTTN' 'FZD4' 'BHMT' 'ABCB1' 'DUSP23' 'THBS1'
#  'F2RL1' 'P4HB' 'CLPTM1L' 'SLC9A3R1' 'MAOB' 'LPCAT1' 'TGFA' 'SEZ6L2'
#  'BNIP3' 'AEBP1' 'TFPI2' 'STC2' 'SIAE' 'RHOC' 'CDK18' 'HSPB8' 'SLC37A4'
#  'TMEM98' 'PROM1' 'CUBN' 'GPRC5C' 'NEFL' 'NEK6' 'PTPRF' 'LRP2' 'FLNB'
#  'CDH1' 'GYS1' 'NTN4' 'LAMP2' 'ACE2' 'APOL1' 'CAV2' 'FAT1' 'CD109'
#  'AKR1B1']
# Top genes in 4:
# ['CIITA' 'CLEC10A' 'CXCR4' 'ECRG4' 'CD1C' 'FCER1A' 'MYH9' 'NR4A1' 'SMAP2'
#  'CCN2' 'FBLN5' 'EEF1G' 'SFRP1' 'SYNPO2' 'PDGFRA' 'CYP1B1' 'CCN1' 'CD1E'
#  'ADAM8' 'CD1D' 'SLIT3' 'LENG8' 'PDGFRB' 'ICOSLG' 'CCDC80' 'CCR2' 'PALLD'
#  'ACAP1' 'CCL19' 'GABBR1' 'ADAMTS1' 'ZNF683' 'DDX39B' 'FRZB' 'AOC3'
#  'ADGRE5' 'TNC' 'ITGAX' 'CFP' 'TCF21' 'MYLK' 'TNXB' 'NLRP1' 'CTLA4'
#  'NDRG2' 'NPY1R' 'FMO3' 'COL5A1' 'CFLAR' 'NLRP3' 'ADGRA2' 'MFGE8' 'MYCL'
#  'FILIP1L' 'TINAGL1' 'CD3E' 'CSRP1' 'LOXL1' 'PARM1' 'EPAS1' 'CFH' 'COL4A4'
#  'FLT3' 'BAD' 'SNAI2' 'PLEKHO1' 'JAK3' 'MAPK8IP3' 'SHFL' 'TYK2' 'BATF3'
#  'MSN' 'MYH10' 'PID1' 'CD4' 'STAT6' 'MRC1' 'NOTCH2' 'HTR4' 'MICAL2' 'VCL'
#  'KDM6B' 'FCMR' 'SVEP1' 'SOD3' 'LTBP1' 'FGR' 'IKZF3' 'S1PR3' 'PI4KA'
#  'ZBTB16' 'WAS' 'PTGIR' 'CACNA1C' 'FCN1' 'CD1B' 'CCR6' 'ZMIZ2' 'ARHGEF2'
#  'PDE5A']
# Top genes in 5:
# ['STAT1' 'LGMN' 'CTSL' 'GRN' 'LIPA' 'TAP1' 'SDC3' 'CYP27A1' 'WARS' 'GBP5'
#  'CYBA' 'GBP1' 'SCPEP1' 'CD68' 'CTSC' 'IGF2R' 'SIGLEC1' 'NR1H3' 'ANXA2'
#  'CREG1' 'LAMP1' 'TYMP' 'CTSA' 'MX1' 'ACP5' 'LTA4H' 'APOL6' 'CD38' 'IFIT3'
#  'SLAMF7' 'SOAT1' 'CXCL9' 'ITGB2' 'LGALS9' 'IRF1' 'STAT2' 'ITGAX' 'TAP2'
#  'TNFRSF14' 'GLA' 'GSTO1' 'OAS3' 'APOL2' 'UCP2' 'PLA2G7' 'HSPA8' 'CEBPA'
#  'CD82' 'ITGAL' 'PGD' 'MSR1' 'CD84' 'ADGRE5' 'MVP' 'FERMT3' 'RAB7A' 'SGK1'
#  'NCF1' 'CCR1' 'PDIA3' 'BLVRA' 'GRB2' 'PLEKHM2' 'DMXL2' 'CMKLR1' 'IFIT2'
#  'GNS' 'SGSH' 'SNX10' 'CXCL10' 'CORO1C' 'IFI35' 'MRC2' 'NLRC5' 'ZFYVE26'
#  'FUCA1' 'IDH1' 'PFKFB3' 'PLAUR' 'TREM2' 'STK40' 'APOL1' 'STAT5A' 'VAMP5'
#  'NCEH1' 'G6PD' 'OAS1' 'CD4' 'APOL3' 'ADAR' 'NCF2' 'MAP7D1' 'GLB1' 'CD72'
#  'MAFB' 'EIF4A1' 'VEGFB' 'PLEKHB2' 'ACE' 'HMOX1']
# Top genes in 6:
# ['CXCR4' 'SGK1' 'SORL1' 'ST14' 'IL13RA1' 'IFNGR1' 'ALDH2' 'NDRG1' 'PADI2'
#  'TLR2' 'ALOX5' 'CSF2RA' 'FCGR2A' 'CIITA' 'LDHA' 'ANGPTL4' 'MEF2A' 'KCNC3'
#  'HIPK2' 'CSF3R' 'FCGR3A' 'PTGS1' 'PEA15' 'PICALM' 'AOAH' 'INPP5D' 'AXL'
#  'PABPC4' 'HSPA6' 'ANKRD44' 'RUNX2' 'CA9' 'CTNND1' 'CD300A' 'ANPEP'
#  'CASS4' 'MAOA' 'PGK1' 'TREM2' 'GSTM3' 'PKM' 'VEGFA' 'AKR1B1' 'PLEC'
#  'ACLY' 'CTSH' 'RAC1' 'HK2' 'FCGR2B' 'PLIN2' 'CA12' 'TBXAS1' 'DST' 'DAPK1'
#  'PFKP' 'CXCL16' 'SLC43A2' 'PLAUR' 'NFE2L2' 'NIBAN1' 'SERPINB9' 'GTF2I'
#  'DPYD' 'PER1' 'SEMA4D' 'EIF3C' 'SLC7A7' 'IRS2' 'ENPEP' 'HNRNPA1L2'
#  'ITGA4' 'TSPAN14' 'C3AR1' 'RASSF4' 'NUMA1' 'ZFAND5' 'NONO' 'CD70' 'TLR5'
#  'CDKN1A' 'IFI16' 'TIPARP' 'CDH6' 'PFKFB3' 'EGLN3' 'CLEC5A' 'CLEC7A'
#  'ERRFI1' 'TUBB' 'PLEKHO1' 'JDP2' 'TYK2' 'FAM117B' 'TKT' 'KCNMB1' 'GNAI2'
#  'PRCP' 'CTNNA1' 'MSR1' 'NR4A3']
# Top genes in 7:
# ['CXCR4' 'CD14' 'SLCO2B1' 'CD4' 'STAB1' 'SMAP2' 'CIITA' 'MSR1' 'CSF1R'
#  'GRN' 'MAN2B1' 'THEMIS2' 'CD163' 'IRS2' 'PLEC' 'ITGB2' 'PFKFB3' 'PLAUR'
#  'ZNF683' 'AP1B1' 'TNFRSF1B' 'NR4A3' 'EEF1G' 'MYO1F' 'LENG8' 'ICOSLG'
#  'WAS' 'ADAM8' 'PER1' 'ALOX5' 'METRNL' 'CLEC10A' 'CD3E' 'CTLA4' 'ZAP70'
#  'KCNA3' 'SGK1' 'ACAP1' 'HSPA6' 'LCK' 'FCGBP' 'TREM1' 'HTR4' 'UMOD'
#  'ZBTB16' 'GAA' 'C5AR1' 'TCF7' 'GRK2' 'CH25H' 'SDK2' 'CARD9' 'ITK' 'NLRP3'
#  'FES' 'NLRP6' 'EPHA1' 'ABTB1' 'IKZF3' 'CD5' 'LTK' 'PTGS2' 'CD40LG' 'CCR2'
#  'CD6' 'COMP' 'BAD' 'MYH9' 'ANGPTL6' 'GNB3' 'SLAMF1' 'OSM' 'NR4A1' 'ECRG4'
#  'CCL19' 'UBASH3A' 'MRAP2' 'EREG' 'CXCR3' 'IL11' 'POU2AF1' 'TWIST2'
#  'CYP17A1' 'CCL24' 'REN' 'ATF3' 'PILRA' 'GREM1' 'PWWP3A' 'LTBP2' 'MIAT'
#  'CLEC4M' 'MAL' 'PDGFRA' 'OTOF' 'PROX1' 'EZHIP' 'CCR3' 'INHBA' 'CCN4']
# Top genes in 8:
# ['CFP' 'ITGAL' 'MSN' 'PECAM1' 'ADGRE5' 'SEPTIN9' 'PLVAP' 'RARA' 'FGR'
#  'NCF2' 'HCK' 'PTPN6' 'SH2D3C' 'TKT' 'WARS' 'EPAS1' 'TNFRSF1B' 'VASP'
#  'SLC9A3R2' 'SPN' 'FYN' 'ITGB2' 'COL4A1' 'LILRA5' 'LILRB2' 'CD34' 'FCN1'
#  'HSPG2' 'SPTBN1' 'LTA4H' 'NAAA' 'ECE1' 'APP' 'MYH9' 'CD300E' 'INSR'
#  'ADGRE2' 'KDR' 'ENG' 'PODXL' 'ESM1' 'DUSP6' 'GIMAP8' 'YWHAZ' 'SHANK3'
#  'PRKCB' 'SELPLG' 'IRF1' 'CSK' 'ANXA2' 'GABBR1' 'PTK2B' 'MYD88' 'ZYX'
#  'TCF7L2' 'RHOC' 'STAT6' 'MYO1F' 'FAM117B' 'TSPAN14' 'RHOA' 'SIRPB1'
#  'AP2A1' 'RELT' 'HK1' 'ICAM3' 'GNAI2' 'IL17RA' 'COL4A2' 'UTRN' 'ABI3'
#  'WAS' 'SPI1' 'NLRP1' 'ICAM2' 'PRKAR1A' 'CD44' 'NOTCH2' 'TES' 'GJA1'
#  'IL3RA' 'LILRB3' 'MCAM' 'PPP1R9B' 'LILRB1' 'PIEZO1' 'ITGA4' 'SMAP2'
#  'LILRA1' 'ERG' 'HDAC1' 'RASSF5' 'SULF2' 'WWTR1' 'ACTN4' 'IMPDH1' 'S1PR1'
#  'CALCRL' 'SVIL' 'PTP4A3']
# Top genes in 9:
# ['ZNF683' 'ICOSLG' 'BAD' 'ECRG4' 'SHFL' 'HTR4' 'CCN2' 'PDGFRA' 'MRC1'
#  'FBLN5' 'CYP17A1' 'NR4A1' 'UMOD' 'TCF21' 'TNXB' 'SYNPO2' 'CCN1' 'PDGFRB'
#  'ANGPTL6' 'SFRP1' 'PRMT8' 'SVEP1' 'RNASE3' 'CALB1' 'REN' 'SLIT3' 'AOC3'
#  'POTEF' 'CHODL' 'COL4A4' 'HOXB7' 'IL11' 'NPY1R' 'KCNQ4' 'CCN4' 'TRIM67'
#  'CACNA1C' 'BMP5' 'GPR137' 'DAZL' 'PAH' 'NFATC4' 'FGFBP2' 'SIX1'
#  'ATP6V1B1' 'GPR3' 'MEIS1' 'SLC22A8' 'NTF3' 'ID4' 'PRRT2' 'PLA2R1' 'ASPN'
#  'SCNN1G' 'CCBE1' 'AJAP1' 'RNF112' 'PTH1R' 'GNB3' 'TMPRSS2' 'GAP43'
#  'GRHL2' 'SIM2' 'IGFN1' 'HRH4' 'ALX1' 'MEG3' 'GREM1' 'PLG' 'GP5' 'CASR'
#  'AFM' 'DACT2' 'TBX3' 'GRM2' 'CNMD' 'PKNOX2' 'SOSTDC1' 'HPSE2' 'PRTN3'
#  'SERPINA5' 'NOS1' 'COL11A1' 'GLI1' 'FAIM2' 'TNNT2' 'FOXI1' 'TFAP2B'
#  'DACH1' 'PGR' 'CCDC102B' 'PLIN5' 'FREM1' 'SLC5A2' 'LIPE' 'GLI2' 'CPEB1'
#  'HSD11B2' 'MYO18B' 'PYGM']
# Top genes in 10:
# ['STAB1' 'SLCO2B1' 'CD14' 'CD163' 'MRC1' 'F13A1' 'SIGLEC1' 'LILRB5'
#  'CD209' 'ZNF683' 'ECRG4' 'LTBP2' 'LGMN' 'COLEC12' 'UMOD' 'LDLR' 'HTR4'
#  'GNB3' 'CLEC4M' 'EGFL7' 'PDGFRA' 'CYP17A1' 'IL12RB2' 'NLRP6' 'REN'
#  'POTEF' 'MMP9' 'SCN9A' 'FCER2' 'SLITRK4' 'FOXI1' 'CCL24' 'SFRP1' 'CALB1'
#  'CCDC141' 'BAD' 'IRGM' 'AGTR1' 'CCN5' 'PAH' 'CXCL2' 'NXPH2' 'SLC6A3'
#  'SLC22A8' 'GRM2' 'UCA1' 'IL11' 'EGF' 'NOS1' 'CCL13' 'PRMT8' 'CHODL'
#  'FZD9' 'SIX1' 'CCBE1' 'CCKBR' 'DTX1' 'GP1BA' 'CCL8' 'KCNQ4' 'SLC5A2'
#  'SERPINB5' 'UNC5A' 'SERPINA5' 'NKX2-3' 'MASP2' 'DAZL' 'SLC30A8' 'ICAM5'
#  'LTK' 'LACRT' 'NPSR1' 'PTH1R' 'DPPA2' 'SERPINB2' 'HS3ST5' 'FUT3' 'PCBP3'
#  'ID4' 'FAT2' 'RIMS4' 'CCDC33' 'BFSP2' 'PCGEM1' 'TGM3' 'TBX4' 'NPFFR2'
#  'SOX14' 'CAMK2B' 'PASD1' 'IL22' 'RXFP1' 'PTPN5' 'NR0B2' 'TTPA' 'FEZF2'
#  'PAX5' 'TMPRSS2' 'EN2' 'KCNK16']
# Top genes in 11:
# ['CD14' 'SLCO2B1' 'CD4' 'GRN' 'MSR1' 'CD163' 'STAB1' 'F13A1' 'AP1B1'
#  'LTBP2' 'LGMN' 'MAN2B1' 'FCGBP' 'FOLR2' 'GAS6' 'SIGLEC1' 'CR1' 'CLEC4M'
#  'LILRB5' 'CD209' 'ECRG4' 'HTR4' 'UMOD' 'CYP17A1' 'MRC1' 'PRMT8' 'ITGAD'
#  'SLC40A1' 'DTX1' 'PTGIS' 'GRIN2D' 'SH2D1A' 'SLC4A1' 'SEMA3D' 'LDLR' 'FEV'
#  'IL12RB2' 'SV2C' 'EN1' 'CCL11' 'HRH4' 'CGB3' 'CCNA1' 'TNF' 'SORCS2'
#  'ERFE' 'NTN1' 'CHD5' 'DAZL' 'NDNF' 'HTR2B' 'TRIM67' 'UNC5A' 'MAPK8IP2'
#  'FST' 'SLC22A8' 'SSTR4' 'TMEFF2' 'PAX1' 'SORCS1' 'GNRHR' 'MMP8'
#  'SERPINB4' 'KLF14' 'USP29' 'HBG1' 'FGF19' 'ACRV1' 'MAGEA11' 'IL36G'
#  'GPR63' 'IL34' 'MUC5AC' 'GALP' 'SERPINB2' 'CACNA1B' 'POU3F4' 'PTH1R'
#  'NR0B2' 'FETUB' 'FOXE3' 'FAT2' 'FOXN1' 'BMP8A' 'ATP6V1B1' 'MTNR1B' 'RTL1'
#  'FOXE1' 'HTR2C' 'CH25H' 'KCNQ4' 'KCNH1' 'HCRTR1' 'SLC6A5' 'PASD1' 'NXPH2'
#  'EGR4' 'GABRA2' 'PAPPA' 'TAC1']
